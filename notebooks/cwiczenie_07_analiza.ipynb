# %%
imie = "Jakub"
nazwisko = "Molendowski"
ID = 35695
id_20 = 1 + ID % 30

print(f"Imię: {imie}")
print(f"Nazwisko: {nazwisko}")
print(f"ID: {ID}")
print(f"id_20: {id_20}")
# Out:
# Imię: Jakub
# Nazwisko: Molendowski
# ID: 35695
# id_20: 26

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install pyspark -q

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Kolokwium_Molendowski") \
    .config("spark.driver.memory", "2g") \
    .getOrCreate()

print(f"Sesja PySpark utworzona: {spark.sparkContext.appName}")
print(f"Spark version: {spark.version}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3746675554.py in <cell line: 0>()
#      10     .appName("Kolokwium_Molendowski") \
#      11     .config("spark.driver.memory", "2g") \
# ---> 12     .getOrCreate()
#      13
#      14 print(f"Sesja PySpark utworzona: {spark.sparkContext.appName}")
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     554     # to Python 3.9.6 (https://github.com/python/cpython/pull/28838)
# ...

# %%
# Download Spark distribution
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz

# Extract Spark distribution
# !tar -xf spark-3.5.1-bin-hadoop3.tgz

# Set environment variables for Java and Spark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"
os.environ["PATH"] = os.environ["SPARK_HOME"] + "/bin:" + os.environ["PATH"]

print("Spark downloaded, extracted, and environment variables configured.")
